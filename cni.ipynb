# %% [markdown]
# <a href="https://colab.research.google.com/github/Kling0012/00py/blob/master/cni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install accelerate diffusers transformers scipy ftfy basicsr facexlib gfpgan safetensors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 17.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 KB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 108.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 KB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 KB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 116.7 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline, DEISMultistepScheduler
 
model_id = "/content/drive/MyDrive/001/002/cni"
 
pipe = StableDiffusionPipeline.from_pretrained(model_id, custom_pipeline="lpw_stable_diffusion")
pipe.scheduler = DEISMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")
# Out:
# /usr/local/lib/python3.8/dist-packages/huggingface_hub/file_download.py:629: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   warnings.warn(
# ...

# %%
# %cp /content/drive/MyDrive/001/safety_checker.py /usr/local/lib/python3.8/dist-packages/diffusers/pipelines/stable_diffusion/safety_checker.py

# %%
import diffusers
from diffusers import StableDiffusionPipeline, DEISMultistepScheduler
import torch
import datetime

x="girl,coming,Sensual appearance, Slinky and form-fitting outfit, Seductive expression with full lips, Bedroom eyes with heavy eyelashes, Glossy and luscious hair with a dark color (e.g. black or deep brown), High heels or thigh-high boots, Sultry and moody lighting, Intense and dramatic background with a focus on texture and detail, Accessories like statement earrings or a choker necklace,cute,puer,young,loli,"
x="best quality, ultra high res, (photorealistic:1.4),4k,8k,cell shaded,nsfw,18+,touch vagina"+x
z="female reproductive organs,flat color, flat shading,bad fingers, bad anatomy, missing fingers,signature, watermark, username, artist name,retro style, poor quality"

#"<lora:koreanDollLikeness_v10:0.8>, best quality, ultra high res, (photorealistic:1.4),"+
prompt = x
negative_prompt =z+ "beard,paintings, sketches, (worst quality:2), (low quality:2), (normal quality:2), lowres, normal quality, ((monochrome)), ((grayscale)), skin spots, acnes, skin blemishes, age spot"

num= 30
for j in range(num):
  y=datetime.datetime.now()
  image = pipe(
      prompt,guidance_scale=6,negative_prompt=negative_prompt,
      width=512,
      height=512,
    ).images[0]
  image.save(f"/content/drive/MyDrive/high/Real-ESRGAN/inputs/00ni{y}.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from google.colab import runtime
runtime.unassign()
