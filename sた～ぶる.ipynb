# %% [markdown]
# <a href="https://colab.research.google.com/github/Kling0012/00py/blob/master/s%E3%81%9F%EF%BD%9E%E3%81%B6%E3%82%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://kurokumasoft.com/2023/01/25/stable-diffusion-anime-style-models/

# %% [markdown]
# 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

# %%
# !pip install diffusers accelerate diffusers transformers scipy ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 KB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.5 MB/s eta 0:00:00
# ...

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

access_token = "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"

# モデルのダウンロード
model = StableDiffusionPipeline.from_pretrained("gsdf/Counterfeit-V2.5", use_auth_token="access_token")
model.to("cuda")
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

def start(x,y):
  prompt = x

  # 1000枚画像を作りたい場合
  num_images = 3
  for j in range(num_images):
      with autocast("cuda"):
          image = model(prompt).images[0] 
          # 500×500px画像が生成
          # 画像サイズを変更したい場合
          # image = model(prompt, height=400, width=400).images[0]

      # save images (本コードでは、直下に画像が生成されていきます。)
      image.save(f"/content/drive/MyDrive/outputs/{y}_{j}.png")

x="anime red bloodcostu cool redmagic ffxiv rapier human boy goodface　Red Mage  Robe Hat Staff  circle Magic effects Magic lights Ritual "
name="02"
start(x,name)
